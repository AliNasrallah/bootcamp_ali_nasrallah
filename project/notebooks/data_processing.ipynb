# %% [markdown]
# # Data Preprocessing

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_parquet("../data/processed/api_source-yfinance_symbol-['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA']_20250820-193757.parquet")
df.head()
# Out:
#   ('Date', '')  ('Adj Close', 'AAPL')  ('Adj Close', 'AMZN')  \
# 0   2020-08-17             111.480759             159.120499
# 1   2020-08-18             112.409706             165.624496
# 2   2020-08-19             112.550751             163.024002
# 3   2020-08-20             115.048210             164.868500
# 4   2020-08-21             120.976913             164.235992
#
#    ('Adj Close', 'GOOG')  ('Adj Close', 'MSFT')  ('Adj Close', 'TSLA')  \
# 0              75.450508             201.466232             122.375999
# 1              77.469513             202.625534             125.806000
# 2              76.919281             201.396179             125.235336
# 3              78.620171             206.082993             133.455338
# 4              78.554077             204.584763             136.665329
#
#    ('Close', 'AAPL')  ('Close', 'AMZN')  ('Close', 'GOOG')  ('Close', 'MSFT')  \
# 0         114.607498         159.120499          75.899002         210.279999
# ...

# %%
print(df.shape)
# Out:
# (1256, 31)

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256 entries, 0 to 1255
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ('Date', '')           1256 non-null   datetime64[ns]
#  1   ('Adj Close', 'AAPL')  1256 non-null   float64
#  2   ('Adj Close', 'AMZN')  1256 non-null   float64
#  3   ('Adj Close', 'GOOG')  1256 non-null   float64
#  4   ('Adj Close', 'MSFT')  1256 non-null   float64
#  5   ('Adj Close', 'TSLA')  1256 non-null   float64
#  6   ('Close', 'AAPL')      1256 non-null   float64
#  7   ('Close', 'AMZN')      1256 non-null   float64
#  8   ('Close', 'GOOG')      1256 non-null   float64
#  9   ('Close', 'MSFT')      1256 non-null   float64
#  10  ('Close', 'TSLA')      1256 non-null   float64
#  11  ('High', 'AAPL')       1256 non-null   float64
#  12  ('High', 'AMZN')       1256 non-null   float64
#  13  ('High', 'GOOG')       1256 non-null   float64
# ...

# %% [markdown]
# No need to handle for missing values because there are none

# %%
df.columns = ['_'.join(col.strip('()').replace("'","").split(", ")) if col != "('Date', '')" else 'Date' for col in df.columns]

# %%
df.head()
# Out:
#         Date  Adj Close_AAPL  Adj Close_AMZN  Adj Close_GOOG  Adj Close_MSFT  \
# 0 2020-08-17      111.480759      159.120499       75.450508      201.466232
# 1 2020-08-18      112.409706      165.624496       77.469513      202.625534
# 2 2020-08-19      112.550751      163.024002       76.919281      201.396179
# 3 2020-08-20      115.048210      164.868500       78.620171      206.082993
# 4 2020-08-21      120.976913      164.235992       78.554077      204.584763
#
#    Adj Close_TSLA  Close_AAPL  Close_AMZN  Close_GOOG  Close_MSFT  ...  \
# 0      122.375999  114.607498  159.120499   75.899002  210.279999  ...
# 1      125.806000  115.562500  165.624496   77.930000  211.490005  ...
# 2      125.235336  115.707497  163.024002   77.376503  209.699997  ...
# 3      133.455338  118.275002  164.868500   79.087502  214.580002  ...
# 4      136.665329  124.370003  164.235992   79.021004  213.020004  ...
#
# ...
